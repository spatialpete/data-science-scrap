# %%
#https://developers.arcgis.com/python/guide/working-with-feature-layers-and-features/

import os
import datetime as dt
import pandas as pd
import numpy as np
import seaborn as sns
import json
import requests
import matplotlib.pyplot as plt

import sklearn
from sklearn import cluster
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

from arcgis import GIS, features, GeoAccessor, GeoSeriesAccessor, geometry
from arcgis.features import SpatialDataFrame
import arcgis

#url = 'https://<insert your Cityworks or AGOL Feature Service>/FeatureServer/2/query?f=json&returnGeometry=true&spatialRel=esriSpatialRelIntersects&maxAllowableOffset=38&inSR=102100&outFields=*&outSR=102100'

url = 'https://services.arcgis.com/v400IkDOw1ad7Yad/arcgis/rest/services'

print('setup complete')
# Out:
# setup complete

# %%
#get list of feature layers
#https://automatetheboringstuff.com/2e/chapter12/

res = requests.get('https://services.arcgis.com/v400IkDOw1ad7Yad/arcgis/rest/services')
try:
    res.raise_for_status()
except Exception as exc:
    print('There was a problem: %s' % (exc))
print(res.text[:10000])
# Out:
# <html lang="en">
# <head>
#   <title>Folder: /</title>
#   <link href='/ESRI.ArcGIS.SDS.REST.css' rel='stylesheet' type='text/css'>
#   <link rel='SHORTCUT ICON' href='/favicon.ico'>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
#   <meta name="keywords" content="ArcGIS REST Services Directory Root">
# </head>
# <body>
# <table width="100%" class="userTable">
# <tr>
# <td class="titlecell">ArcGIS REST Services Directory</td>
# </tr>
# </table>
# <table class="navTable" width="100%">
# <tbody>
# <tr valign="top">
# <td class="breadcrumbs">
# <a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services">Home</a> > <a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services">services</a> </td>
# <td align="right">
# <a href="http://resources.arcgis.com/en/help/arcgis-rest-api/" target="_blank">API Reference</a></td>
# </tr>
# </tbody>
# </table>
# <table>
# <tr>
# <td class="apiref">
# <a href="?f=pjson" target="_blank">JSON</a>
# </td>
# </tr>
# </table>
# <div class='restHeader'>
# <h2>Folder: /</h2>
# </div>
# <div class='restBody'>
# <b>Current Version:</b> 10.81<br/>
# <br/>
# <b>Services:</b> <br/>
# <br/>
# <ul id='servicesList'>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/1_5_Mile_Radius_Battalions_Current/FeatureServer">1_5_Mile_Radius_Battalions_Current</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/12_30_2019_PrecDNR/FeatureServer">12_30_2019_PrecDNR</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2009_2019_update_tiles/FeatureServer">2009_2019_update_tiles</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2010_2019/FeatureServer">2010_2019</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2010ACSData/FeatureServer">2010ACSData</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2019_ChangeMap_WFL1/FeatureServer">2019_ChangeMap_WFL1</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2019_Plan_update_WFL1/FeatureServer">2019_Plan_update_WFL1</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2020_Final_Street_Resurfacing_View/FeatureServer">2020_Final_Street_Resurfacing_View</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2020_Raleigh_Change_Map/FeatureServer">2020_Raleigh_Change_Map</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2020_Rejuvenation_Contract_Viewer/FeatureServer">2020_Rejuvenation_Contract_Viewer</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2021_Street_Resurfacing_V1/FeatureServer">2021_Street_Resurfacing_V1</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/2050_MTP_Local_Plans_Review_Data/FeatureServer">2050_MTP_Local_Plans_Review_Data</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/56e7ae324b4547deae2d76246ff6c38b_view_1576068134059/FeatureServer">56e7ae324b4547deae2d76246ff6c38b_view_1576068134059</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/a1dc29/FeatureServer">a1dc29</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AADT2017Avg_BlockGroups/FeatureServer">AADT2017Avg_BlockGroups</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AAS_Program_Data/FeatureServer">AAS_Program_Data</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Abbotts_Creek_Park/FeatureServer">Abbotts_Creek_Park</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Abbotts_Creek_Participants_WFL1/FeatureServer">Abbotts_Creek_Participants_WFL1</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/ACS_2018_Hispanic_or_Latino_By_Tract/FeatureServer">ACS_2018_Hispanic_or_Latino_By_Tract</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/ACS_2018_Hispanic_or_Latino_By_Tract_Raleigh/FeatureServer">ACS_2018_Hispanic_or_Latino_By_Tract_Raleigh</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Active_Road_Closures_Florence/FeatureServer">Active_Road_Closures_Florence</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/ADA_Parking_Spaces_Proposed/FeatureServer">ADA_Parking_Spaces_Proposed</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopt_App_Users/FeatureServer">Adopt_App_Users</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AdoptAStops_public/FeatureServer">AdoptAStops_public</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopted_Capital_Projects/FeatureServer">Adopted_Capital_Projects</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopted_Expense_Budget/FeatureServer">Adopted_Expense_Budget</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopted_Expense_Budget_Current_Fiscal_Year/FeatureServer">Adopted_Expense_Budget_Current_Fiscal_Year</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopted_Revenue_Budget/FeatureServer">Adopted_Revenue_Budget</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Adopted_Revenue_Budget_Current_Fiscal_Year/FeatureServer">Adopted_Revenue_Budget_Current_Fiscal_Year</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AdoptionAddresses%20Density/FeatureServer">AdoptionAddresses Density</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AerialLighting/FeatureServer">AerialLighting</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AffordableHousing_Geocoded/FeatureServer">AffordableHousing_Geocoded</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/All%20Dog%20Friendly%20Apartments%20Density/FeatureServer">All Dog Friendly Apartments Density</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/All%20Events%20Density/FeatureServer">All Events Density</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Alley_Inventory/FeatureServer">Alley_Inventory</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Annexation_Agreement_Properties/FeatureServer">Annexation_Agreement_Properties</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Annexation_History_1792_to_2009/FeatureServer">Annexation_History_1792_to_2009</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AnnexationAgreements/FeatureServer">AnnexationAgreements</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Apartments_and_Dog_Parks/FeatureServer">Apartments_and_Dog_Parks</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Area_Outside_CityLimits/FeatureServer">Area_Outside_CityLimits</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Area_Plan_Boundaries/FeatureServer">Area_Plan_Boundaries</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Area_Plans/FeatureServer">Area_Plans</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/ArtBeats_Locations/FeatureServer">ArtBeats_Locations</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AssetForm/FeatureServer">AssetForm</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AssetFormL/FeatureServer">AssetFormL</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/AssetMaintenance/FeatureServer">AssetMaintenance</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Assets_WSL1/FeatureServer">Assets_WSL1</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Assets_WSL1/SceneServer">Assets_WSL1</a> (SceneServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/ATT_Point_Distance/FeatureServer">ATT_Point_Distance</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Basin_Metrics_per_basin_Feb2021_View/FeatureServer">Basin_Metrics_per_basin_Feb2021_View</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Basin_Stats/FeatureServer">Basin_Stats</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Battalions_2020/FeatureServer">Battalions_2020</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Benthic_Sites/FeatureServer">Benthic_Sites</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Benthic_Survey/FeatureServer">Benthic_Survey</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bicycle_Parking_Facilities/FeatureServer">Bicycle_Parking_Facilities</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bicycle_Shops/FeatureServer">Bicycle_Shops</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Friendly_Businesses/FeatureServer">Bike_Friendly_Businesses</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Parking/FeatureServer">Bike_Parking</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Parking_Public_View/FeatureServer">Bike_Parking_Public_View</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Ped_Infrastructure_Implemented_with_BRT/FeatureServer">Bike_Ped_Infrastructure_Implemented_with_BRT</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Routes/FeatureServer">Bike_Routes</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/Bike_Shops/FeatureServer">Bike_Shops</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/BikeRaleigh/FeatureServer">BikeRaleigh</a> (FeatureServer)</li>
# <li><a href="/v400IkDOw1ad7Yad/ArcGIS/rest/services/BikeRaleigh_Long_Term_Plan_Editing/FeatureServer
